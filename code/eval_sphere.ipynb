# %%
#Impact of all TraceIDs

import pandas as pd
import plotly.express as px

gen = 50

ci_df = pd.read_csv("../data/preliminary_test_data/counting_impact.csv")
#only_last_gen = data[data.generation == data.generation.max()]
only_last_gen_ci = ci_df[ci_df.generation == gen]
only_last_gen_ci['random_population'] = only_last_gen_ci[['traceID_2', 'traceID_3', 'traceID_4', 'traceID_5', 'traceID_6', 'traceID_7', 'traceID_8', 'traceID_9', 'traceID_10', 'traceID_11', 'traceID_12', 'traceID_13', 'traceID_14', 'traceID_15', 'traceID_16', 'traceID_17', 'traceID_18', 'traceID_19', 'traceID_20']].sum(axis=1)
#only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.crossover_type == "combining"]


#CI of Fitness = 1
f1_df = only_last_gen_ci[only_last_gen_ci.seed_fitness ==1]
print(f1_df)
fig = px.box(f1_df[['traceID_1', 'random_population', 'traceID_m', 'percentage_of_optimal_genes']], color="percentage_of_optimal_genes", title="fitness = 1")
fig.show()
#CI of Fitness = 4
f1_df = only_last_gen_ci[only_last_gen_ci.seed_fitness ==4]
fig = px.box(f1_df.drop(columns=['generation', 'run_number', 'seed_fitness', 'crossover_type', 'dim']), color="percentage_of_optimal_genes", title="fitness = 4")
fig.show()
#CI of Fitness = 9
f1_df = only_last_gen_ci[only_last_gen_ci.seed_fitness ==9]
fig = px.box(f1_df.drop(columns=['generation', 'run_number', 'seed_fitness', 'crossover_type', 'dim']), color="percentage_of_optimal_genes", title="fitness = 9")
fig.show()
#CI of Fitness = 16
f1_df = only_last_gen_ci[only_last_gen_ci.seed_fitness ==16]
fig = px.box(f1_df.drop(columns=['generation', 'run_number', 'seed_fitness', 'crossover_type', 'dim']), color="percentage_of_optimal_genes", title="fitness = 16")
fig.show()
# Out:
# /var/folders/wp/_16y9p6573n_95q3dky8ktjm0000gp/T/ipykernel_96145/528451799.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_last_gen_ci['random_population'] = only_last_gen_ci[['traceID_2', 'traceID_3', 'traceID_4', 'traceID_5', 'traceID_6', 'traceID_7', 'traceID_8', 'traceID_9', 'traceID_10', 'traceID_11', 'traceID_12', 'traceID_13', 'traceID_14', 'traceID_15', 'traceID_16', 'traceID_17', 'traceID_18', 'traceID_19', 'traceID_20']].sum(axis=1)
#         generation  traceID_1  traceID_2  traceID_3  traceID_4  traceID_5  \
# 21749           50   0.645338   0.000000        0.0   0.015144   0.000000
# 21799           50   0.707460   0.000002        0.0   0.048227   0.000000
# ...

# %%
#Impact values for the median seed fitness individuum only to compare the different values for crossove rand dimensions

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp

gen = 50

ci_df = pd.read_csv("../data/sphere_function_data_out/counting_impact.csv")
only_last_gen_ci = ci_df[ci_df.generation == gen]
only_last_gen_ci['random_population'] = only_last_gen_ci[['traceID_2', 'traceID_3', 'traceID_4', 'traceID_5', 'traceID_6', 'traceID_7', 'traceID_8', 'traceID_9', 'traceID_10', 'traceID_11', 'traceID_12', 'traceID_13', 'traceID_14', 'traceID_15', 'traceID_16', 'traceID_17', 'traceID_18', 'traceID_19', 'traceID_20']].sum(axis=1)

#filter runs with optimal and worst point:
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.seed_quality == "median"]
only_last_gen_ci = only_last_gen_ci[['traceID_1', 'random_population', 'traceID_m', 'percentage_of_optimal_genes', 'dim', 'crossover']]


#CI of Fitness = 1
fig = px.box(
    only_last_gen_ci,
    color="percentage_of_optimal_genes",
    facet_col="dim",
    facet_row="crossover",
    labels={
            "value": "counting impact",
            "variable": "",
            "percentage_of_optimal_genes": "% optimal genes",
            "traceID_1" : "seed ind"
        },
    height=700, width=1400)

fig.write_image("figures/genome_quality_distribution_impact.pdf")
fig.show()
# Out:
# /var/folders/wp/_16y9p6573n_95q3dky8ktjm0000gp/T/ipykernel_96145/1694454179.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Performance values for the median seed fitness individuum only

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp

gen = 50

performance_df = pd.read_csv("../data/sphere_function_data_out/performance.csv")
only_last_gen_performance = performance_df[performance_df.generation == gen]

#filter runs with optimal and worst point:
#only_last_gen_performance = only_last_gen_performance[only_last_gen_performance.seed_quality != "udopia"]
#only_last_gen_performance = only_last_gen_performance[only_last_gen_performance.seed_quality != "dystopia"]
only_last_gen_performance = only_last_gen_performance[only_last_gen_performance.seed_quality == "median"]
only_last_gen_performance = only_last_gen_performance[['min_f', 'percentage_of_optimal_genes', 'dim', 'crossover']]


#CI of Fitness = 1
fig = px.box(
    only_last_gen_performance,
    color="percentage_of_optimal_genes",
    facet_col="dim",
    facet_row="crossover",
    labels={
            "value": "fitness",
            "variable": "",
            "percentage_of_optimal_genes": "% optimal genes",
            "traceID_1" : "seed ind"
        },
    height=700, width=1400)
fig.update_yaxes(matches=None)#don't share the y axis

fig.write_image("figures/genome_vs_fitness_impact.pdf")
fig.show()

# %%
#Impact values for dimension 8 only

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp

gen = 50
dim = 8

ci_df = pd.read_csv("../data/sphere_function_data_out/counting_impact.csv")
only_last_gen_ci = ci_df[ci_df.generation == gen]
only_last_gen_ci['random_population'] = only_last_gen_ci[['traceID_2', 'traceID_3', 'traceID_4', 'traceID_5', 'traceID_6', 'traceID_7', 'traceID_8', 'traceID_9', 'traceID_10', 'traceID_11', 'traceID_12', 'traceID_13', 'traceID_14', 'traceID_15', 'traceID_16', 'traceID_17', 'traceID_18', 'traceID_19', 'traceID_20']].sum(axis=1)

#filter runs with optimal and worst point:
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.dim == 8]
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.seed_quality != "udopia"]
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.seed_quality != "dystopia"]
only_last_gen_ci = only_last_gen_ci[['traceID_1', 'random_population', 'traceID_m', 'percentage_of_optimal_genes', 'seed_quality', 'crossover']]


#CI of Fitness = 1
fig = px.box(
    only_last_gen_ci,
    color="percentage_of_optimal_genes",
    facet_col="seed_quality",
    facet_row="crossover",
    labels={
            "value": "counting impact",
            "variable": "",
            "percentage_of_optimal_genes": "% optimal genes",
            "traceID_1" : "seed ind"
        },
    height=700, width=1400)

fig.write_image("figures/genome_vs_fitness_impact.pdf")
fig.show()
# Out:
# /var/folders/wp/_16y9p6573n_95q3dky8ktjm0000gp/T/ipykernel_96145/320692621.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Performance values for dimension 8 only

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp

gen = 50
dim = 8

performance_df = pd.read_csv("../data/sphere_function_data_out/performance.csv")
only_last_gen_performance = performance_df[performance_df.generation == gen]

#filter runs with optimal and worst point:
only_last_gen_performance = only_last_gen_performance[only_last_gen_performance.dim == 8]
only_last_gen_performance = only_last_gen_performance[only_last_gen_performance.seed_quality != "udopia"]
only_last_gen_performance = only_last_gen_performance[only_last_gen_performance.seed_quality != "dystopia"]
only_last_gen_performance = only_last_gen_performance[['min_f', 'percentage_of_optimal_genes', 'seed_quality', 'crossover']]


#CI of Fitness = 1
fig = px.box(
    only_last_gen_performance,
    color="percentage_of_optimal_genes",
    facet_col="seed_quality",
    facet_row="crossover",
    labels={
            "value": "fitness",
            "variable": "",
            "percentage_of_optimal_genes": "% optimal genes",
            "traceID_1" : "seed ind"
        },
    height=700, width=1400)
fig.update_yaxes(matches=None)#don't share the y axis

fig.write_image("figures/genome_vs_fitness_performance.pdf")
fig.show()

# %%
# Visualize single test run performance
import pandas as pd
import plotly.express as px

dim = 8

performance_df = pd.read_csv("../data/sphere_function_data_out/performance.csv")

performance_df = performance_df[performance_df.crossover == "UX"].drop(columns=["crossover"])
performance_df = performance_df[performance_df.seed_quality == "median"].drop(columns=["seed_quality"])

mean_performance_df = performance_df.groupby(["percentage_of_optimal_genes", "seed_fitness", "generation", "dim", "problem"], as_index=False).median()


fig = px.line(
    mean_performance_df[mean_performance_df.dim ==dim],
    y="min_f",
    x="generation",
    color="percentage_of_optimal_genes",
    labels={
        "value": "fitness",
        "variable": "generation",
        "percentage_of_optimal_genes": "% optimal genes",
    },
    )
fig.update_layout(yaxis_type="log")
fig.write_image("figures/single_run_case_study_performance.pdf")
fig.show()

# %%
#Single run case study Impact

import pandas as pd
import plotly.express as px

gen = 50
dim = 8

ci_df = pd.read_csv("../data/sphere_function_data_out/counting_impact.csv")
only_last_gen_ci = ci_df[ci_df.generation == gen]
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.dim == dim]
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.crossover == "UX"]
only_last_gen_ci = only_last_gen_ci.rename(columns={"traceID_1": "seed_ind"})

#CI of Fitness = 9
only_last_gen_ci = only_last_gen_ci[only_last_gen_ci.seed_quality == "median"]
fig = px.box(
    only_last_gen_ci.drop(columns=['generation', 'run_number', 'seed_quality', 'seed_fitness', 'crossover', 'dim', 'problem']),
    color="percentage_of_optimal_genes",
    width=800, height=600,
    labels={
        "value": "impact",
        "variable": "",
        "percentage_of_optimal_genes": "% optimal genes",
    },
    )

fig.write_image("figures/single_run_case_study_performance.pdf")
fig.show()

# %%
#Fitness in the initial pop

import pandas as pd
import plotly.express as px

gen = 1
dim = 8

fitness_df = pd.read_csv("../data/sphere_function_data_out/fitness.csv")
fitness_df = fitness_df[fitness_df.generation == gen]
fitness_df = fitness_df[fitness_df.dim == dim]
fitness_df = fitness_df[fitness_df.crossover == "UX"]
fitness_df = fitness_df[fitness_df.seed_quality == "median"]
fitness_df = fitness_df[fitness_df.percentage_of_optimal_genes == 0]
fitness_df = fitness_df[fitness_df.run_number == 0].drop(columns = ["generation", "dim", "crossover", "seed_quality", "seed_fitness", "run_number", "percentage_of_optimal_genes", "problem", "individual"])
fitness_df = fitness_df.reset_index(drop=True)
fitness_df.index = fitness_df.index + 1
#TODO: filter all the things

print(fitness_df)

#CI of Fitness = 9
fig = px.bar(
    fitness_df,
    x=fitness_df.index[1:],
    y=fitness_df.f[1:],
    width=800, height=600
    )

fig.update_layout(
    xaxis = dict(
        tickmode = 'linear',
        tick0 = 2,
        dtick = 1
    )
)

fig.write_image("figures/single_run_case_study_performance.pdf")
fig.show()
# Out:
#             f
# 1    9.260386
# 2    6.565419
# 3    9.512614
# 4    5.956312
# 5    9.260386
# 6   11.586545
# 7   13.539218
# 8    7.731139
# 9    8.059961
# 10  11.033725
# 11   9.897523
# 12   7.293520
# 13   9.511304
# 14   4.304439
# 15   7.125096
# 16  10.493465
# 17  10.643259
# 18   7.031507
# 19  13.305106
# 20   8.473950
